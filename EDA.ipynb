# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


train_df = pd.read_csv(r'data\traindata.csv')
train_df.shape
# Out:
# (20000, 4000)

# %%
# train_df.to_csv('data/traindata.csv', index=False)
train_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.289038  2.709899  2.158200  1.773029  2.017148  2.171430  1.962698
# 1  2.816199  3.361174  2.994411  2.297843  2.181683  2.523456  2.613175
# 2  0.279536  0.095345 -0.574250 -0.632244 -0.371651 -0.444289 -0.605033
# 3 -1.463680 -1.838429 -2.360350 -2.273260 -2.153206 -2.309917 -2.351108
# 4 -0.653054 -1.064762 -1.620217 -1.438040 -1.239214 -1.379585 -1.386661
#
#           7         8         9  ...      3990      3991      3992      3993  \
# 0  1.811876  1.907563  1.956386  ...  2.630065  2.679228  2.604173  2.427846
# 1  2.407619  2.293488  2.424912  ...  1.718569  1.579311  1.446814  1.560291
# 2 -0.543184 -0.453719 -0.423799  ... -2.145604 -2.151338 -2.100819 -2.123218
# 3 -2.239255 -2.195544 -2.143254  ... -0.750538 -0.785712 -0.736137 -0.688817
# 4 -1.212440 -1.146213 -1.133551  ... -0.980496 -1.033847 -1.015707 -0.980561
#
#        3994      3995      3996      3997      3998      3999
# 0  2.508991  2.697032  2.545371  2.254294  2.673253  3.328534
# 1  1.745784  1.628296  1.349219  1.544226  2.163641  2.240235
# 2 -2.222960 -2.141128 -2.029926 -2.188975 -2.243896 -1.764339
# 3 -0.808618 -0.855745 -0.681326 -0.756792 -1.035035 -0.677503
# 4 -1.109546 -1.185886 -1.006779 -1.022982 -1.279313 -0.961549
#
# [5 rows x 4000 columns]

# %%
test_df = pd.read_csv(r'data\testdata.csv')
test_df.shape
# Out:
# (10000, 4000)

# %%
# test_df.to_csv('data/testdata.csv', index=False)
test_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.396707 -0.436091 -0.366740 -0.329037 -0.353421 -0.367535 -0.344384
# 1  0.200663  0.224369  0.193099  0.174940  0.185680  0.191206  0.178698
# 2 -0.009275 -0.016903 -0.024812 -0.031616 -0.036174 -0.038222 -0.038956
# 3  3.298252  3.749155  3.333355  3.127922  3.375659  3.521394  3.375659
# 4 -0.107651 -0.120867 -0.106364 -0.100196 -0.109473 -0.116193 -0.115478
#
#           7         8         9  ...      3990      3991      3992      3993  \
# 0 -0.324497 -0.327260 -0.328179  ... -0.787231 -0.756421 -0.765826 -0.786143
# 1  0.167620  0.167207  0.166017  ...  0.085313  0.088434  0.098259  0.108933
# 2 -0.039911 -0.041507 -0.042873  ... -0.197333 -0.194322 -0.201275 -0.211283
# 3  3.257443  3.317754  3.361269  ... -0.358749 -0.356360 -0.378250 -0.395059
# 4 -0.117185 -0.122233 -0.121261  ...  0.036134  0.031250  0.032917  0.040653
#
#        3994      3995      3996      3997      3998      3999
# 0 -0.747750 -0.688753 -0.728723 -0.815338 -0.715880 -0.356645
# 1  0.107932  0.103738  0.118259  0.141078  0.127787  0.064613
# 2 -0.204753 -0.192313 -0.206376 -0.232050 -0.203594 -0.101382
# 3 -0.372250 -0.344206 -0.378250 -0.436975 -0.387851 -0.193514
# 4  0.045462  0.045459  0.049215  0.056099  0.050394  0.025649
#
# [5 rows x 4000 columns]

# %%
train_df.describe()
# Out:
#                   0             1             2             3             4  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       0.523684      0.358664      0.049960     -0.184366     -0.301166
# std        1.612739      1.691709      1.682589      1.618943      1.576357
# min      -30.440870    -34.433374    -21.766163    -22.221594    -21.395475
# 25%       -0.262704     -0.494288     -0.823529     -0.994905     -1.129217
# 50%        0.309884      0.139283     -0.036038     -0.204396     -0.303801
# 75%        0.899475      0.739214      0.445994      0.178692      0.074607
# max        8.617871      8.983726      8.479304     26.876819     35.693976
#
#                   5             6             7             8             9  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -0.359923     -0.406815     -0.433858     -0.435341     -0.417519
# std        1.556601      1.548949      1.553249      1.536063      1.522736
# min      -19.740118    -18.057530    -17.059717    -16.594565    -16.105601
# 25%       -1.204815     -1.239102     -1.237291     -1.224714     -1.193029
# 50%       -0.339324     -0.381362     -0.421905     -0.429470     -0.411783
# 75%        0.022018     -0.016391     -0.042491     -0.051547     -0.056891
# max       17.191810      7.969317     32.250496     31.521790     29.494088
#
#        ...          3990          3991          3992          3993  \
# count  ...  20000.000000  20000.000000  20000.000000  20000.000000
# mean   ...     -0.257756     -0.248383     -0.232271     -0.204747
# std    ...      1.417468      1.417226      1.421916      1.431458
# min    ...     -8.929726     -8.933032     -8.929583     -8.916072
# 25%    ...     -0.952257     -0.949492     -0.941775     -0.927828
# 50%    ...     -0.288087     -0.288089     -0.279950     -0.250965
# 75%    ...     -0.045835     -0.038191     -0.026077     -0.009843
# max    ...      8.003823      8.159100      8.200423      7.982250
#
#                3994          3995          3996          3997          3998  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -0.162975     -0.116836     -0.060087      0.039213      0.205729
# std        1.442783      1.444163      1.461518      1.509165      1.582994
# min       -8.945092     -8.933968     -8.915499     -8.910312     -8.988183
# 25%       -0.906074     -0.867536     -0.817610     -0.736398     -0.645218
# 50%       -0.208525     -0.170985     -0.140807     -0.073928      0.017893
# 75%        0.023997      0.070697      0.128673      0.254722      0.481156
# max        7.608620      7.596129      7.953632      7.890991      7.860820
#
#                3999
# count  20000.000000
# mean       0.376266
# std        1.602810
# min       -8.904789
# 25%       -0.456286
# 50%        0.116989
# 75%        0.687399
# max        8.469659
#
# [8 rows x 4000 columns]

# %%
def fft_plot(signal, fs, duration=None):
    
    n = len(signal)
    if duration is None:
        duration = n/fs
    t = np.linspace(0, duration, n)
    
    fft_result = np.fft.fft(signal)
    freq = np.fft.fftfreq(n, 1/fs)
    
    phase = np.angle(fft_result)
    
    plt.figure(figsize=(12, 9))
    
    plt.subplot(3, 1, 1)
    plt.plot(t, signal)
    plt.title('Original Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    plt.subplot(3, 1, 2)
    freq_range = n // 2
    plt.plot(freq[:freq_range], np.abs(fft_result)[:freq_range]*2/n)
    plt.title('Frequency Spectrum (Magnitude)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Magnitude')
    plt.grid(True)

    plt.subplot(3, 1, 3)
    plt.plot(freq[:n//2], phase[:n//2])
    plt.title('Frequency Spectrum (Phase)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Phase (radians)')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

sample_ill_signal = train_df.loc[0]
fft_plot(sample_ill_signal, fs=400, duration=10)

# %%
def get_fft(signal, fs=400):
    fft_result = np.fft.fft(signal)
    n = len(signal)
    freq = np.fft.fftfreq(n, 1/fs)
    freq_range = n // 2
    phase = np.angle(fft_result)

    return np.abs(fft_result)[:freq_range]*2/n, phase[:freq_range]

fft_result, phase = get_fft(sample_ill_signal)
fft_result, phase = pd.DataFrame(fft_result), pd.DataFrame(phase)
fft_result.describe()
# Out:
#                  0
# count  2000.000000
# mean      0.008231
# std       0.137382
# min       0.000047
# 25%       0.000513
# 50%       0.000763
# 75%       0.001832
# max       5.237659

# %%
phase.describe()
# Out:
#                  0
# count  2000.000000
# mean      1.448052
# std       1.877634
# min      -3.141196
# 25%       0.189118
# 50%       2.363058
# 75%       2.999682
# max       3.141180

# %%
freq_df = pd.DataFrame()
freq_df['fft_mean'] = train_df.apply(lambda x: get_fft(x)[0].mean(), axis=1)
freq_df['fft_std'] = train_df.apply(lambda x: get_fft(x)[0].std(), axis=1)
freq_df['phase_mean'] = train_df.apply(lambda x: get_fft(x)[1].mean(), axis=1)
freq_df['phase_std'] = train_df.apply(lambda x: get_fft(x)[1].std(), axis=1)

# %%
freq_df.head()
# Out:
#    fft_mean   fft_std  phase_mean  phase_std
# 0  0.008231  0.137348    1.448052   1.877165
# 1  0.006302  0.085169   -1.108253   1.238360
# 2  0.005328  0.059139   -0.535131   0.751475
# 3  0.004983  0.062093    1.374070   1.556889
# 4  0.003691  0.047995    0.572238   1.714020

# %%
sample_healthy_signal = train_df.loc[500]
fft_plot(sample_healthy_signal, fs=400, duration=10)

# %%
sample_test_signal = test_df.loc[0]
fft_plot(sample_test_signal, fs=400, duration=10)

# %%
# 1 for has the disease, 0 for does not have the disease, -1 for unlabeled
train_df['target'] = -1
train_df.iloc[0:500, -1] = 1
train_df.iloc[500:1000, -1] = 0
freq_df['target'] = train_df['target']

train_df['target'].value_counts()
# Out:
# target
# -1    19000
#  1      500
#  0      500
# Name: count, dtype: int64

# %%
labeled_train_df = train_df[train_df['target'] != -1]
labeled_freq_df = freq_df[freq_df['target'] != -1]

target = labeled_train_df['target']
labeled_train_df = labeled_train_df.drop(columns='target')
labeled_freq_df = labeled_freq_df.drop(columns='target')
labeled_train_df.shape
# Out:
# (1000, 4000)

# %%
labeled_train_df[0:500].describe()
# Out:
#                 0           1           2           3           4           5  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.747487   -0.838626   -1.047498   -1.131919   -1.132302   -1.124476
# std      1.010194    1.023254    1.003915    0.984946    0.983184    0.981379
# min     -8.064656   -8.511249   -8.882476   -8.980185   -8.897894   -8.905806
# 25%     -1.250639   -1.359292   -1.525587   -1.633822   -1.587290   -1.583343
# 50%     -0.597534   -0.828136   -0.954131   -1.006586   -0.987101   -1.024371
# 75%     -0.235343   -0.382819   -0.645212   -0.704949   -0.718183   -0.708952
# max      4.324068    4.782564    5.476878    5.548499    5.014663    4.516283
#
#                 6           7           8           9  ...        3990  \
# count  500.000000  500.000000  500.000000  500.000000  ...  500.000000
# mean    -1.127769   -1.123162   -1.094353   -1.062045  ...   -1.029570
# std      0.958089    0.942007    0.936803    0.926154  ...    0.732420
# min     -8.946566   -8.946836   -8.914055   -8.922413  ...   -7.066634
# 25%     -1.548660   -1.572032   -1.517095   -1.447774  ...   -1.179028
# 50%     -1.002173   -0.986743   -0.961874   -0.950579  ...   -0.977460
# 75%     -0.717634   -0.748769   -0.741321   -0.731406  ...   -0.790866
# max      4.452562    4.677497    4.741565    4.530093  ...    2.630065
#
#              3991        3992        3993        3994        3995        3996  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -1.035814   -1.043086   -1.041866   -1.026745   -1.010987   -1.021068
# std      0.728707    0.726669    0.733973    0.747802    0.746797    0.737354
# min     -7.047989   -6.968645   -6.891301   -6.896199   -6.893022   -6.776784
# 25%     -1.184418   -1.187818   -1.222587   -1.212333   -1.211701   -1.208780
# 50%     -0.976814   -0.989836   -0.980127   -1.000980   -0.991439   -1.013477
# 75%     -0.802339   -0.785151   -0.760818   -0.734283   -0.730754   -0.734779
# max      2.679228    2.604173    2.427846    2.508991    2.697032    2.545371
#
#              3997        3998        3999
# count  500.000000  500.000000  500.000000
# mean    -1.021487   -0.974934   -0.892519
# std      0.735304    0.764692    0.810602
# min     -6.499557   -6.324352   -6.328164
# 25%     -1.238508   -1.224233   -1.187484
# 50%     -0.996502   -0.978832   -0.918310
# 75%     -0.756916   -0.675366   -0.530908
# max      2.254294    2.673253    3.328534
#
# [8 rows x 4000 columns]

# %%
labeled_train_df[500:].describe()
# Out:
#                 0           1           2           3           4           5  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.458976    0.299554    0.133491    0.019348   -0.048884   -0.102833
# std      0.386697    0.344124    0.282307    0.267510    0.271998    0.271494
# min     -1.016994   -1.003310   -1.157854   -1.398632   -1.620391   -1.791198
# 25%      0.198254    0.059172   -0.013325   -0.072045   -0.178586   -0.253383
# 50%      0.411018    0.296549    0.121542    0.034415   -0.006769   -0.065431
# 75%      0.739944    0.511464    0.288352    0.150883    0.096363    0.055635
# max      2.077776    1.955586    1.919262    1.796447    1.566180    1.362053
#
#                 6           7           8           9  ...        3990  \
# count  500.000000  500.000000  500.000000  500.000000  ...  500.000000
# mean    -0.153675   -0.177433   -0.165260   -0.136423  ...   -0.129749
# std      0.276472    0.275382    0.259941    0.239910  ...    0.218142
# min     -1.890674   -1.933025   -1.925829   -1.866206  ...   -1.277004
# 25%     -0.338711   -0.379268   -0.351594   -0.279112  ...   -0.237691
# 50%     -0.092911   -0.106406   -0.113973   -0.115316  ...   -0.120177
# 75%      0.025328    0.006764   -0.003624    0.002264  ...   -0.042402
# max      1.260470    1.239085    1.202490    1.119162  ...    1.396537
#
#              3991        3992        3993        3994        3995        3996  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.143631   -0.155920   -0.156274   -0.132607   -0.098745   -0.063639
# std      0.228434    0.240847    0.250240    0.248244    0.240584    0.237168
# min     -1.298712   -1.313438   -1.309220   -1.371651   -1.527001   -1.340420
# 25%     -0.280084   -0.323560   -0.337111   -0.287251   -0.221204   -0.177794
# 50%     -0.127641   -0.127703   -0.120210   -0.112416   -0.096210   -0.068007
# 75%     -0.045137   -0.035072   -0.032380   -0.028618   -0.023191   -0.000222
# max      1.381736    1.449017    1.600467    1.796636    1.951484    2.013763
#
#              3997        3998        3999
# count  500.000000  500.000000  500.000000
# mean     0.000704    0.127997    0.285167
# std      0.236010    0.261083    0.328784
# min     -1.158572   -1.093111   -0.965387
# 25%     -0.088969   -0.021074    0.027909
# 50%     -0.024777    0.085586    0.264101
# 75%      0.059078    0.243537    0.492063
# max      1.967613    1.904015    1.895229
#
# [8 rows x 4000 columns]

# %%
def statistics_plot(df, freq_df, cutedge=500, linerange=4000):
    t = np.linspace(0, linerange, linerange)
    plt.figure(figsize=(16, 20))
    
    # Plot 1: Standard Deviation
    plt.subplot(3, 2, 1)
    disease_std = df[:cutedge].std(axis=0)  
    healthy_std = df[cutedge:].std(axis=0)

    sns.lineplot(x=t, y=disease_std, label='Has Disease')
    sns.lineplot(x=t, y=healthy_std, label='Healthy')

    plt.title('Standard Deviation of Signals')
    plt.xlabel('sample point')
    plt.ylabel('Standard Deviation')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # Plot 2: Mean with confidence interval (bulging region)
    plt.subplot(3, 2, 2)
    disease_mean = df[:cutedge].mean(axis=0)
    healthy_mean = df[cutedge:].mean(axis=0)
    
    # Calculate standard error for confidence bands
    disease_se = df[:cutedge].sem(axis=0)
    healthy_se = df[cutedge:].sem(axis=0)
    
    # Plot mean lines
    plt.plot(t, disease_mean, label='Has Disease', color='blue')
    plt.plot(t, healthy_mean, label='Healthy', color='orange')
    
    # Add shaded confidence intervals (bulging regions)
    plt.fill_between(t, disease_mean-disease_se, disease_mean+disease_se, 
                     alpha=0.3, color='blue', label='_nolegend_')
    plt.fill_between(t, healthy_mean-healthy_se, healthy_mean+healthy_se, 
                     alpha=0.3, color='orange', label='_nolegend_')

    plt.title('Mean of Signals')
    plt.xlabel('sample point')
    plt.ylabel('Mean Magnitude')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # ============================================================================
    plt.subplots_adjust(hspace=0.15)
    num_points = np.linspace(0, cutedge, cutedge)
    
    # Plot 3: FFT Mean with confidence interval
    plt.subplot(3, 2, 3)
    disease_fft_mean = freq_df[:cutedge]['fft_mean']
    healthy_fft_mean = freq_df[cutedge:]['fft_mean']
    
    # Get standard error for FFT mean
    disease_fft_se = freq_df[:cutedge]['fft_std'] / np.sqrt(len(freq_df[:cutedge]))
    healthy_fft_se = freq_df[cutedge:]['fft_std'] / np.sqrt(len(freq_df[cutedge:]))
    
    # Plot mean lines
    plt.plot(num_points, disease_fft_mean, label='Has Disease', color='blue')
    plt.plot(num_points, healthy_fft_mean, label='Healthy', color='orange')
    
    # Add shaded confidence intervals
    plt.fill_between(num_points, disease_fft_mean-disease_fft_se, disease_fft_mean+disease_fft_se, 
                     alpha=0.3, color='blue', label='_nolegend_')
    plt.fill_between(num_points, healthy_fft_mean-healthy_fft_se, healthy_fft_mean+healthy_fft_se, 
                     alpha=0.3, color='orange', label='_nolegend_')

    plt.title('Mean FFT result')
    plt.xlabel('data point')
    plt.ylabel('Mean FFT Result')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # Plot 4: Phase Mean with confidence interval
    plt.subplot(3, 2, 4)
    disease_phase_mean = freq_df[:cutedge]['phase_mean']
    healthy_phase_mean = freq_df[cutedge:]['phase_mean']
    
    # Get standard error for phase mean
    disease_phase_se = freq_df[:cutedge]['phase_std'] / np.sqrt(len(freq_df[:cutedge]))
    healthy_phase_se = freq_df[cutedge:]['phase_std'] / np.sqrt(len(freq_df[cutedge:]))
    
    # Plot mean lines
    plt.plot(num_points, disease_phase_mean, label='Has Disease', color='blue')
    plt.plot(num_points, healthy_phase_mean, label='Healthy', color='orange')
    
    # Add shaded confidence intervals
    plt.fill_between(num_points, disease_phase_mean-disease_phase_se, disease_phase_mean+disease_phase_se, 
                     alpha=0.3, color='blue', label='_nolegend_')
    plt.fill_between(num_points, healthy_phase_mean-healthy_phase_se, healthy_phase_mean+healthy_phase_se, 
                     alpha=0.3, color='orange', label='_nolegend_')

    plt.title('Mean phase result')
    plt.xlabel('data point')
    plt.ylabel('Mean phase Result')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # Plot 5: FFT Standard Deviation
    plt.subplot(3, 2, 5)
    disease_fft_std = freq_df[:cutedge]['fft_std']
    healthy_fft_std = freq_df[cutedge:]['fft_std']

    sns.lineplot(x=num_points, y=disease_fft_std, label='Has Disease')
    sns.lineplot(x=num_points, y=healthy_fft_std, label='Healthy')

    plt.title('FFT std result')
    plt.xlabel('data point')
    plt.ylabel('FFT std Result')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # Plot 6: Phase Standard Deviation
    plt.subplot(3, 2, 6)
    disease_phase_std = freq_df[:cutedge]['phase_std']
    healthy_phase_std = freq_df[cutedge:]['phase_std']

    sns.lineplot(x=num_points, y=disease_phase_std, label='Has Disease')
    sns.lineplot(x=num_points, y=healthy_phase_std, label='Healthy')

    plt.title('Phase std result')
    plt.xlabel('data point')
    plt.ylabel('Phase std Result')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()

statistics_plot(labeled_train_df, labeled_freq_df)

# %%
from src.utils import SignalOps

WINDOW = 200
def differential_plot(healthy, ill, duration=4000, title='Differential Plot', label1='origin', label2='transformed'):
    healthy_origin = healthy[0]
    healthy_transformed = healthy[1]
    t = np.linspace(0, duration, duration)
    plt.figure(figsize=(16, 12))

    plt.subplot(2, 2, 1)
    sns.lineplot(x=t, y=healthy_origin, label=label1)
    sns.lineplot(x=t, y=healthy_transformed, label=label2)
    plt.title(title)
    plt.xlabel('sample point')
    plt.ylabel('Magnitude')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(2, 2, 2)
    sns.lineplot(x=t, y=healthy_origin, label=label1)
    sns.lineplot(x=t, y=healthy_origin-healthy_transformed, label=label1 + '-' + label2)
    plt.title(title)
    plt.xlabel('sample point')
    plt.ylabel('Magnitude')
    plt.legend()

    plt.subplots_adjust(hspace=0.3)
    ill_origin = ill[0]
    ill_transformed = ill[1]

    plt.subplot(2, 2, 3)
    sns.lineplot(x=t, y=ill_origin, label=label1)
    sns.lineplot(x=t, y=ill_transformed, label=label2)
    plt.title(title)
    plt.xlabel('sample point')
    plt.ylabel('Magnitude')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.subplot(2, 2, 4)
    sns.lineplot(x=t, y=ill_origin, label=label1)
    sns.lineplot(x=t, y=ill_origin-ill_transformed, label=label1 + '-' + label2)
    plt.title(title)
    plt.xlabel('sample point')
    plt.ylabel('Magnitude')
    plt.legend()

    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

sample_healthy_signal = labeled_train_df.loc[500]
sample_ill_signal = labeled_train_df.loc[0]
healthy_sample = (sample_healthy_signal, SignalOps.moving_average(sample_healthy_signal, window_length=WINDOW))
ill_sample = (sample_ill_signal, SignalOps.moving_average(sample_ill_signal, window_length=WINDOW))
differential_plot(healthy_sample, ill_sample, title='Original Signal vs Moving Average Signal', label1='Original Signal', label2='Moving Average Signal')

# %%
sample_healthy_signal = labeled_train_df.loc[503]
sample_ill_signal = labeled_train_df.loc[3]
healthy_peaks = SignalOps.peaks(sample_healthy_signal, sample_healthy_signal.mean()+sample_healthy_signal.std())
ill_peaks = SignalOps.peaks(sample_ill_signal, sample_ill_signal.mean()+sample_ill_signal.std())
healthy_peaks.shape, ill_peaks.shape
# Out:
# ((30,), (112,))

# %%
ps_healthy = SignalOps.ps_density(sample_healthy_signal, nperseg=512)[1]
ps_ill = SignalOps.ps_density(sample_ill_signal, nperseg=512)[1]

ps_healthy.shape, ps_ill.shape
# Out:
# ((257,), (257,))

# %%
NPERSEG = 1024
labeled_freq_df['peaks'] = labeled_train_df.apply(lambda x: SignalOps.peaks(x, x.mean() + x.std()).shape[0], axis=1)
labeled_freq_df['ps_density_mean'] = labeled_train_df.apply(lambda x: SignalOps.ps_density(x, nperseg=NPERSEG)[1].mean(), axis=1)
labeled_freq_df['ps_density_std'] = labeled_train_df.apply(lambda x: SignalOps.ps_density(x, nperseg=NPERSEG)[1].std(), axis=1)
labeled_freq_df['entropy'] = labeled_freq_df.apply(lambda x: SignalOps.entropy(x), axis=1)

def df_signal_feature_plot(df, cutedge=500):
    t = np.linspace(0, cutedge, cutedge)
    ill_df = df[:cutedge]
    healty_df = df[cutedge:]
    plt.figure(figsize=(16, 12))

    plt.subplot(2, 2, 1)
    sns.lineplot(x=t, y=healty_df['peaks'], label='Healthy')
    sns.lineplot(x=t, y=ill_df['peaks'], label='Has Disease')
    plt.title('Peaks Count')
    plt.xlabel('Sample point')
    plt.ylabel('Count')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(2, 2, 2)
    sns.lineplot(x=t, y=healty_df['ps_density_mean'], label='Healthy')
    sns.lineplot(x=t, y=ill_df['ps_density_mean'], label='Has Disease')
    plt.title('PS Density Mean')
    plt.xlabel('sample point')
    plt.ylabel('PS Density Mean')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplots_adjust(hspace=0.3)

    plt.subplot(2, 2, 3)
    sns.lineplot(x=t, y=healty_df['ps_density_std'], label='Healthy')
    sns.lineplot(x=t, y=ill_df['ps_density_std'], label='Has Disease')
    plt.title('PS Density Std')
    plt.xlabel('sample point')
    plt.ylabel('PS Density Std')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(2, 2, 4)
    sns.lineplot(x=t, y=healty_df['entropy'], label='Healthy')
    sns.lineplot(x=t, y=ill_df['entropy'], label='Has Disease')
    plt.title('Entropy')
    plt.xlabel('sample point')
    plt.ylabel('Entropy')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

df_signal_feature_plot(labeled_freq_df)

# %%
labeled_freq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fft_mean         1000 non-null   float64
#  1   fft_std          1000 non-null   float64
#  2   phase_mean       1000 non-null   float64
#  3   phase_std        1000 non-null   float64
#  4   peaks            1000 non-null   int64
#  5   ps_density_mean  1000 non-null   float64
#  6   ps_density_std   1000 non-null   float64
#  7   entropy          1000 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 70.3 KB

# %%
labeled_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Columns: 4000 entries, 0 to 3999
# dtypes: float64(4000)
# memory usage: 30.6 MB

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1000 entries, 0 to 999
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   int64
# dtypes: int64(1)
# memory usage: 47.9 KB
